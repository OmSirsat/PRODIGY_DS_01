# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/india_population.csv")
df
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0   2020  1380004385             0.99       13586631         -532687
# 1   2019  1366417754             1.02       13775474         -532687
# 2   2018  1352642280             1.04       13965495         -532687
# 3   2017  1338676785             1.07       14159536         -532687
# 4   2016  1324517249             1.10       14364846         -532687
# 5   2015  1310152403             1.20       15174247         -470015
# 6   2010  1234281170             1.47       17334249         -531169
# 7   2005  1147609927             1.67       18206876         -377797
# 8   2000  1056575549             1.85       18530592         -136514
# 9   1995   963922588             1.99       18128958         -110590
# 10  1990   873277798             2.17       17783558            9030
# 11  1985   784360008             2.33       17081433          115942
# 12  1980   698952844             2.32       15169989          222247
# ...

# %%
plt.figure(figsize=(12, 8))

# Line plot for Population over the years
plt.subplot(2, 2, 1)
plt.plot(df['Year'], df['Population'], marker='o')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population over the Years')
# Out:
# Text(0.5, 1.0, 'Population over the Years')

# %%
# Bar plot for Yearly % Change
plt.subplot(2, 2, 2)
plt.bar(df['Year'], df['Yearly % Change'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Yearly % Change')
plt.title('Yearly % Change')
# Out:
# Text(0.5, 1.0, 'Yearly % Change')

# %%
# Bar plot for Median Age
plt.subplot(2, 2, 3)
plt.bar(df['Year'], df['Median Age'], color='green')
plt.xlabel('Year')
plt.ylabel('Median Age')
plt.title('Median Age')
# Out:
# Text(0.5, 1.0, 'Median Age')

# %%
# Bar plot for Fertility Rate
plt.subplot(2, 2, 4)
plt.bar(df['Year'], df['Fertility Rate'], color='orange')
plt.xlabel('Year')
plt.ylabel('Fertility Rate')
plt.title('Fertility Rate')
# Out:
# Text(0.5, 1.0, 'Fertility Rate')

# %%
plt.tight_layout()
plt.show()
